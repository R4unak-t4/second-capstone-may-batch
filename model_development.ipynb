# %% [markdown]
# # Model Training and Artifact Generation Notebook
#
# Use this notebook to train any scikit-learn classification model pipeline and export the artifacts (`model.joblib` and `metadata.json`) to the `backend/artifacts/` folder.
#
# The React frontend will automatically read this schema to generate a responsive interface for single and batch predictions.

# %% [markdown]
# ### Step 1: Import Dependencies & Prepare Dataset
# Import standard libraries and load your classification dataset (e.g. Iris, Titanic, or custom data).

# %%
# Import pandas, numpy, scikit-learn pipeline, joblib and json
# load dataset here

# %% [markdown]
# ### Step 2: Define and Train Your Model Pipeline
# Ensure your model uses a `sklearn.pipeline.Pipeline` containing all preprocessing steps (scaling, encoding, vectorization) followed by the classifier. This allows the backend to call `model.predict(X)` directly without manual feature engineering.

# %%
# Train-test split
# Define and fit your Pipeline(s)

# %% [markdown]
# ### Step 3: Define Schema Metadata and Save Artifacts
# Define the model name, features (with bounds or options), target, and metrics. Then dump the pipeline as a `model.joblib` and metadata as `metadata.json` into the `backend/artifacts` folder.

# %%
# Save model.joblib and metadata.json to backend/artifacts/
